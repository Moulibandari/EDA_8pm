# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
a=100
b=200
c=a+b
c
# Out:
# 300

# %%
a=500
b=500
c=a+b
print(c)
# Out:
# 1000

# %%
i like python
# Out:
#   Cell In[3], line 1
#     i like python
#       ^
# SyntaxError: invalid syntax

# %%
# i like python   comment

# %% [markdown]
# today im learning python
# python is very easy

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# ### python

# %% [markdown]
# #### python

# %% [markdown]
# ##### python

# %% [markdown]
# - today im learning
#
# - python is good
#
# - python is very easy
#
# - python is excellent

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %% [markdown]
# ## variables

# %% [markdown]
# - store the value
# - change the value

# %%
number=100
# 100 is a value stored in a variable called number

# %%
print(number)
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
number=200
print(number)
# Out:
# 200

# %% [markdown]
# number1=200
# number2=300
# number1
# number2

# %%
number1=200
number2=300
print(number1)
print(number2)
# Out:
# 200
# 300

# %%
number=100
NUMBER=200

# %%
number
# Out:
# 100

# %%
NUMBER
# Out:
# 200

# %%
number123=400

# %%
number123
# Out:
# 400

# %%
123number=400
# Out:
#   Cell In[19], line 1
#     123number=400
#       ^
# SyntaxError: invalid decimal literal

# %%
number #small case working
NUMBER #capital is working
number123 #numbers as suffix
123number # not working
number@  #not working
# Out:
# 400

# %%
number@=600
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 number@=600
#
# TypeError: unsupported operand type(s) for @=: 'int' and 'int'

# %%
areaoftraingle=100 # working
area_of_traingle=200 # working
area of trangle=300 # fail( not allow)

# %%
number=100 # w
NUMBER=200 # w
Number=300 # w
number one=400 # f 
number_one=500 # w
number@=600 # f
if=700 # f
else=800 # f

# %% [markdown]
# - variable are case sensitive
#
#     -number and NUMBER
#
# - variable can be capital and small letters
#
# - numbers as staring does not allow as variables
#
#     -123number
#
# - varibles does not include spl characters
#
#     -number@
#
# - keywords or reserved words looks like green also not allowed as varaible
#
#     - ex: if else for True False elif def etc

# %%
num=100
print(num)
# Out:
# 100

# %%
type(num)
# Out:
# int

# %%
sum([100,200])
# sum use case is different
# Out:
# 300

# %% [markdown]
# **variable should be black color**

# %%
Sum=300 # correct way
sum=300 # wrong way

# %%
max=500 # it will work but wrong way
Max=500 # correct way

# %%
max([100,200])
# Out:
# 200

# %%
min([100,200])
# Out:
# 100

# %%
print([100,200])   # print
type([100,200])     # type list
sum([100,200])      # 300
max([100,200])      # 200
min([100,200])       # 100
len([100,200])       # 2
# Out:
# [100, 200]
# 2
